# %%
# %%capture

#Instalando o spotipy
# !pip install spotipy

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import BaggingClassifier
import numpy as np
import pandas as pd
import re
import spotipy
from spotipy import util
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='9230b3a140aa47d5976323e954fdb105', client_secret='49ea33f127304b3cb533030a400ce18c')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# Com o novo dataset, como cada música, em muitos casos, têm mais de um gênero e como existem gêneros muito específicos, é necessário juntar alguns gêneros.

# %%
pd.options.mode.chained_assignment = None


data = pd.DataFrame(columns = ['artists','name', 'danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms','genres'])
data = pd.read_csv('data_generos.csv')
data = data.drop('year', axis=1)
data = data.drop('popularity', axis=1)
data = data.drop('loudness', axis=1)


for i,item in enumerate(data['genres']):
    if item != str:
        item = str(item)
    if "hip hop" in item or 'trap' in item or 'rap' in item or 'reggaeton' in item:
        data['genres'][i] = 'hip hop'
    elif "rock" in item:
        data['genres'][i] = 'rock'
    elif "jazz" in item or "lounge" in item:
        data['genres'][i] = 'jazz'
    elif "pop" in item:
        data['genres'][i] = 'pop'
    elif "metal" in item or "punk" in item:
        data['genres'][i] = 'punk/metal'
    elif "country" in item or "folk" in item:
        data['genres'][i] = 'country/folk'
    elif "funk" in item or "disco" in item or 'r&b' in item or 'motown' in item:
        data['genres'][i] = 'funk/disco/r&b'
    elif "edm" in item or "house" in item:
        data['genres'][i] = 'electronic'
    else:
        data['genres'][i] = 'NaN'
    
data
# Out:
#                                      artists  \
# 0                                Chuck Berry
# 1                              Elvis Presley
# 2            Ella Fitzgerald Louis Armstrong
# 3                              Elvis Presley
# 4                              Frank Sinatra
# ..                                       ...
# 695                       Panic At The Disco
# 696  The Chainsmokers ILLENIUM Lennon Stella
# 697                      Alan Walker Ava Max
# 698                                    Drake
# 699                        Ed Sheeran Khalid
#
#                                             name  acousticness  danceability  \
# 0                                Johnny B. Goode        0.7410         0.534
# 1                                 Jailhouse Rock        0.4100         0.647
# 2    Dream A Little Dream Of Me - Single Version        0.9130         0.443
# 3                                      Hound Dog        0.7330         0.357
# 4                  Come Fly With Me - Remastered        0.8450         0.574
# ..                                           ...           ...           ...
# 695                                   High Hopes        0.1930         0.579
# 696                                     Takeaway        0.1260         0.528
# 697                                Alone, Pt. II        0.5360         0.670
# 698                                   God's Plan        0.0332         0.754
# 699              Beautiful People (feat. Khalid)        0.1240         0.640
#
#      energy  instrumentalness  liveness  speechiness  valence    tempo  \
# 0     0.803          0.000061    0.3070       0.0743    0.969  167.983
# 1     0.582          0.000002    0.0715       0.0755    0.915  167.396
# 2     0.104          0.000000    0.1910       0.1010    0.394   76.497
# 3     0.756          0.005050    0.7600       0.0621    0.950  174.797
# 4     0.338          0.000000    0.1650       0.0420    0.493   67.008
# ..      ...               ...       ...          ...      ...      ...
# 695   0.904          0.000000    0.0640       0.0618    0.681   82.014
# 696   0.511          0.000000    0.1010       0.0324    0.351  100.100
# 697   0.668          0.000000    0.1330       0.0422    0.608   88.033
# 698   0.449          0.000083    0.5520       0.1090    0.357   77.169
# 699   0.648          0.000000    0.0802       0.1870    0.548   92.977
#
#      duration_ms      genres
# 0         161560        rock
# 1         146480        rock
# 2         185160        jazz
# 3         136027        rock
# 4         199093        jazz
# ..           ...         ...
# 695       190947        rock
# 696       209880         pop
# 697       179053  electronic
# 698       198973     hip hop
# 699       197867         pop
#
# [700 rows x 12 columns]

# %% [markdown]
# Agora já é possível fazer a Análise Exploratória Inicial:

# %%
data_media = data
data_media = data_media.dropna(axis=0, subset=['genres'])
data_media = data.groupby('genres').mean()
data_media = data_media.drop('NaN')
data_media
# Out:
#                 acousticness  danceability    energy  instrumentalness  \
# genres
# country/folk        0.487300      0.697500  0.511500          0.003445
# electronic          0.302300      0.672000  0.721000          0.000940
# funk/disco/r&b      0.362133      0.654800  0.533667          0.000609
# hip hop             0.161766      0.714134  0.663438          0.001675
# jazz                0.774553      0.499742  0.240406          0.067963
# pop                 0.300065      0.642570  0.626254          0.018791
# punk/metal          0.014260      0.605667  0.801333          0.000340
# rock                0.280626      0.552315  0.637643          0.019060
#
#                 liveness  speechiness   valence       tempo    duration_ms
# genres
# country/folk    0.345500     0.046975  0.742500  104.605000  172257.500000
# electronic      0.263000     0.065700  0.469000  100.041500  177800.000000
# funk/disco/r&b  0.208620     0.076713  0.676467  115.343600  208806.400000
# hip hop         0.198324     0.147211  0.557475  117.660554  233611.946429
# jazz            0.136550     0.052039  0.403771  112.047581  233660.161290
# pop             0.155261     0.070015  0.548837  115.364289  220210.491228
# punk/metal      0.248000     0.066400  0.506667   93.713333  196515.666667
# rock            0.161878     0.052197  0.602174  121.161511  236585.959239

# %% [markdown]
# Os índices vão ser normalizados para que as diferenças fiquem mais nítidas.

# %%
# Normalizando para que as diferenças sejam mais perceptíveis
norm = data_media.apply(lambda x: x/x.max(), axis=0)
norm
# Out:
#                 acousticness  danceability    energy  instrumentalness  \
# genres
# country/folk        0.629137      0.976708  0.638311          0.050682
# electronic          0.390290      0.941000  0.899750          0.013831
# funk/disco/r&b      0.467538      0.916915  0.665973          0.008957
# hip hop             0.208851      1.000000  0.827917          0.024651
# jazz                1.000000      0.699787  0.300007          1.000000
# pop                 0.387403      0.899789  0.781515          0.276488
# punk/metal          0.018411      0.848114  1.000000          0.005009
# rock                0.362306      0.773406  0.795727          0.280447
#
#                 liveness  speechiness   valence     tempo  duration_ms
# genres
# country/folk    1.000000     0.319100  1.000000  0.863352     0.728097
# electronic      0.761216     0.446299  0.631650  0.825687     0.751524
# funk/disco/r&b  0.603821     0.521112  0.911066  0.951982     0.882582
# hip hop         0.574021     1.000000  0.750808  0.971105     0.987429
# jazz            0.395224     0.353498  0.543799  0.924779     0.987633
# pop             0.449382     0.475610  0.739174  0.952153     0.930784
# punk/metal      0.717800     0.451054  0.682379  0.773458     0.830631
# rock            0.468533     0.354575  0.811009  1.000000     1.000000

# %%
# Variancias
seletor = VarianceThreshold()
seletor.fit_transform(norm)
variancas = seletor.variances_


rowvar = pd.DataFrame(variancas.reshape(-1, len(variancas)), columns=norm.columns)

norm = norm.append(rowvar).rename({0: 'variancia'})
norm = norm.sort_values(by='variancia', ascending=False, axis=1)
norm
# Out:
#                 instrumentalness  acousticness  speechiness    energy  \
# country/folk            0.050682      0.629137     0.319100  0.638311
# electronic              0.013831      0.390290     0.446299  0.899750
# funk/disco/r&b          0.008957      0.467538     0.521112  0.665973
# hip hop                 0.024651      0.208851     1.000000  0.827917
# jazz                    1.000000      1.000000     0.353498  0.300007
# pop                     0.276488      0.387403     0.475610  0.781515
# punk/metal              0.005009      0.018411     0.451054  1.000000
# rock                    0.280447      0.362306     0.354575  0.795727
# variancia               0.101761      0.074022     0.041360  0.039385
#
#                 liveness   valence  duration_ms  danceability     tempo
# country/folk    1.000000  1.000000     0.728097      0.976708  0.863352
# electronic      0.761216  0.631650     0.751524      0.941000  0.825687
# funk/disco/r&b  0.603821  0.911066     0.882582      0.916915  0.951982
# hip hop         0.574021  0.750808     0.987429      1.000000  0.971105
# jazz            0.395224  0.543799     0.987633      0.699787  0.924779
# pop             0.449382  0.739174     0.930784      0.899789  0.952153
# punk/metal      0.717800  0.682379     0.830631      0.848114  0.773458
# rock            0.468533  0.811009     1.000000      0.773406  1.000000
# variancia       0.034856  0.019096     0.010212      0.009257  0.005435

# %% [markdown]
# Vou separar o dataset em treinamento e em teste para testar sua precisão com uma classificação Decision Tree.

# %%
X = data.drop(columns=['name', 'artists', 'genres',])
y = data.genres

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
dtc = DecisionTreeClassifier(random_state=39)
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=39, splitter='best')

# %%
dtc.score(X_test, y_test)
# Out:
# 0.5714285714285714

# %% [markdown]
# Vou alterar alguns critérios do Decision tree para aumentar a porcentagem de acertos.

# %%
dtc = DecisionTreeClassifier(max_features=7, random_state=42, max_leaf_nodes=100, max_depth=5, min_samples_split=100)
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=5, max_features=7, max_leaf_nodes=100,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=100,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
dtc.score(X_test, y_test)
# Out:
# 0.6619047619047619

# %% [markdown]
# Agora, irei usar o Bagging Classifier para aumentar ainda mais a porcentagem de acerto.

# %%
# Use our decision tree classifier to create an ensemble, draw 0.8 samples from X to train each estimator
bag = BaggingClassifier(dtc, n_estimators=42, max_samples=0.4, random_state=55)
bag.fit(X_train, y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                         class_weight=None,
#                                                         criterion='gini',
#                                                         max_depth=5,
#                                                         max_features=7,
#                                                         max_leaf_nodes=100,
#                                                         min_impurity_decrease=0.0,
#                                                         min_impurity_split=None,
#                                                         min_samples_leaf=1,
#                                                         min_samples_split=100,
#                                                         min_weight_fraction_leaf=0.0,
#                                                         presort='deprecated',
#                                                         random_state=42,
#                                                         splitter='best'),
#                   bootstrap=True, bootstrap_features=False, max_features=1.0,
#                   max_samples=0.4, n_estimators=42, n_jobs=None,
#                   oob_score=False, random_state=55, verbose=0,
#                   warm_start=False)

# %%
bag.score(X_test, y_test)
# Out:
# 0.6666666666666666

# %% [markdown]
# Apesar de 69% de acerto não ser ideal, já é algo. Vou pesquisar duas músicas no Spotify pelo spotipy para testar o classificador.

# %%
teste = pd.DataFrame(data=None, columns=['danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms'], index=None)
musicas = ['ac/dc back in black', '2pac changes']

i = 0

for z in musicas:
    
    resultados = sp.search(z)

    track_id = resultados['tracks']['items'][0]['id']
        
    features = sp.audio_features(tracks = [track_id])
    
    danceability = features[0]['danceability']
    energy = features[0]['energy']
    speechiness = features[0]['speechiness']
    acousticness = features[0]['acousticness']
    instrumentalness = features[0]['instrumentalness']
    liveness = features[0]['liveness']
    valence = features[0]['valence']
    tempo = features[0]['tempo']
    duration_ms = features[0]['duration_ms']
        
    colunas = [danceability, energy, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms]
    teste.loc[i] = colunas
    i += 1

teste
# Out:
#    danceability  energy  speechiness  acousticness  instrumentalness  \
# 0         0.310   0.700        0.047        0.0110           0.00965
# 1         0.865   0.665        0.073        0.0453           0.00000
#
#    liveness  valence    tempo  duration_ms
# 0    0.0828    0.763  188.386     255493.0
# 1    0.2240    0.331  111.113     268827.0

# %%
for x in range(i):
    print(musicas[x], "=", bag.predict(teste)[x])
# Out:
# ac/dc back in black = rock
# 2pac changes = hip hop
